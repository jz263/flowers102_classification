# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy.misc
# Out:
# Using TensorFlow backend.

# %%
#os.chdir('../')
os.getcwd()
# Out:
# 'C:\\Users\\Jiajie Zhang\\flowers102'

# %%
model = load_model('102flowersmodel.h5')

# %%
img_path = 'test_images/test_moon_orchid_08.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
my_image = plt.imshow(plt.imread(img_path))
x = np.expand_dims(x, axis=0)
print('Input image shape:', x.shape)
print(my_image)
print(model.predict(x))
print(f'predicted class is: {np.argmax(model.predict(x))+1}')
# Out:
# Input image shape: (1, 224, 224, 3)
# AxesImage(54,36;334.8x217.44)
# [[3.1003049e-03 9.4219686e-05 1.7793403e-03 2.9686966e-04 4.3222387e-03
#   7.7916726e-02 5.5337657e-04 9.0943497e-01 2.4984393e-03 3.4491186e-06]]
# predicted class is: 8
